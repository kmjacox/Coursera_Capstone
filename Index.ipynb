# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %%
#Uncomment these if needed
# !conda install -c conda-forge wikipedia --yes
print('Wikipedia Done')
# !conda install -c conda-forge pandasql --yes
print('Pandasql Done')
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
print('geopy Done')
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
print('Folium Done')

# !conda install -c conda-forge matplotlib --yes # uncomment this line if you haven't completed the Foursquare API lab
print('matplotlib Done')
# !conda install -c conda-forge scikit-learn --yes # uncomment this line if you haven't completed the Foursquare API lab
print('scikit-learn Done')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Wikipedia Done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Pandasql Done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# geopy Done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium Done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# matplotlib Done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# scikit-learn Done

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import wikipedia as wp


import pandasql as pdsql

pysql = lambda q: pdsql.sqldf(q, globals())


import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans


import folium # map rendering library

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Set Foursquare variables
CLIENT_ID = 'U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1' # your Foursquare ID
CLIENT_SECRET = '3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1
# CLIENT_SECRET:3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y

# %%
from geopy.geocoders import Nominatim

waddress = 'Woodstock, GA'
raddress = 'Roswell, GA'
geolocator = Nominatim(user_agent="my_explorer")
wlocation = geolocator.geocode(waddress)
rlocation = geolocator.geocode(raddress)
wlatitude = wlocation.latitude
wlongitude = wlocation.longitude
rlatitude = rlocation.latitude
rlongitude = rlocation.longitude
print('The geograpical coordinates of '+waddress+' are {}, {}.'.format(wlatitude, wlongitude))
print('The geograpical coordinates of '+raddress+' are {}, {}.'.format(rlatitude, rlongitude))
# Out:
# The geograpical coordinates of Woodstock, GA are 34.1014112, -84.5192192.
# The geograpical coordinates of Roswell, GA are 34.02332, -84.360022.

# %%
# Make our search
search_query = ''
radius = 1000
categoryid='4d4b7105d754a06374d81259'
LIMIT=100
print(search_query + ' .... OK!')
# Out:
#  .... OK!

# %%
wurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, wlatitude, wlongitude, VERSION, search_query, radius, LIMIT)
wurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1&client_secret=3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y&ll=34.1014112,-84.5192192&v=20180604&query=&radius=1000&limit=100'

# %%
rurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, rlatitude, rlongitude, VERSION, search_query, radius, LIMIT)
rurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1&client_secret=3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y&ll=34.02332,-84.360022&v=20180604&query=&radius=1000&limit=100'

# %%
#Get Results for Woodstock
import requests
wresults = requests.get(wurl).json()
wresults
# Out:
# {'meta': {'code': 200, 'requestId': '5d6584eb5f9e7900267a51db'},
#  'response': {'venues': [{'id': '50b3ac3fe4b0f78dc10d26e6',
#     'name': 'Main St. Woodstock',
#     'location': {'lat': 34.10130943021684,
#      'lng': -84.51945657131313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10130943021684,
#        'lng': -84.51945657131313}],
#      'distance': 24,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f6931735',
#       'name': 'General Travel',
#       'pluralName': 'General Travel',
#       'shortName': 'Travel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4bb498b5a187ef3b1dc84942',
#     'name': 'Main Street Woodstock Inc.',
#     'location': {'address': '8632 Main St',
#      'lat': 34.10055915034406,
#      'lng': -84.51980986862857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10055915034406,
#        'lng': -84.51980986862857}],
#      'distance': 109,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8632 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '530a5c53498e3916df663037',
#     'name': 'Downtown Woodstock',
#     'location': {'lat': 34.101464920387315,
#      'lng': -84.5192620008621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101464920387315,
#        'lng': -84.5192620008621}],
#      'distance': 7,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11a941735',
#       'name': 'Other Nightlife',
#       'pluralName': 'Other Nightlife',
#       'shortName': 'Nightlife',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '593f1b4c09e2831c1992e06e',
#     'name': 'Rootstock & Vine',
#     'location': {'address': '8558 Main St',
#      'crossStreet': 'Townelake Parkway',
#      'lat': 34.10127615264531,
#      'lng': -84.51956079862995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10127615264531,
#        'lng': -84.51956079862995}],
#      'distance': 34,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8558 Main St (Townelake Parkway)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '478525471'},
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b2fe403f964a5200ff224e3',
#     'name': 'Woodstock City Park',
#     'location': {'address': '101 Arnold Mill Rd',
#      'crossStreet': 'Main St',
#      'lat': 34.101692084240526,
#      'lng': -84.51865268392977,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101692084240526,
#        'lng': -84.51865268392977}],
#      'distance': 60,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['101 Arnold Mill Rd (Main St)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '52fcdc8b498e71a5c047bca0',
#     'name': 'Atlantic Gifts & More',
#     'location': {'lat': 34.10149,
#      'lng': -84.51938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10149,
#        'lng': -84.51938}],
#      'distance': 17,
#      'postalCode': '30189',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30189', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '5827af34878188626acdd6e6',
#     'name': 'Woodstock Amphitheater',
#     'location': {'lat': 34.101739,
#      'lng': -84.518101,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101739,
#        'lng': -84.518101}],
#      'distance': 109,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d5734db',
#       'name': 'Amphitheater',
#       'pluralName': 'Amphitheaters',
#       'shortName': 'Amphitheater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b8e78caf964a520522433e3',
#     'name': 'Morgan Ace Hardware',
#     'location': {'address': '109 E Main St',
#      'lat': 34.1001449,
#      'lng': -84.518574,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.1001449,
#        'lng': -84.518574}],
#      'distance': 152,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['109 E Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4be5c52a2468c928fb850043',
#     'name': 'Holly Springs Jewelry',
#     'location': {'address': '510 Chambers St',
#      'crossStreet': 'South Main St.',
#      'lat': 34.10087790249361,
#      'lng': -84.5188307762146,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10087790249361,
#        'lng': -84.5188307762146}],
#      'distance': 69,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['510 Chambers St (South Main St.)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e1b77de62e180a4848f7564',
#     'name': 'The Chambers At City Center',
#     'location': {'address': '8534 Main St',
#      'crossStreet': 'Towne Lake Parkway',
#      'lat': 34.101763461573775,
#      'lng': -84.51969805433372,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101763461573775,
#        'lng': -84.51969805433372}],
#      'distance': 59,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8534 Main St (Towne Lake Parkway)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d129941735',
#       'name': 'City Hall',
#       'pluralName': 'City Halls',
#       'shortName': 'City Hall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/cityhall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4be58e302457a593d79aab15',
#     'name': "Vingenzo's",
#     'location': {'address': '105 E Main St',
#      'lat': 34.102058864478316,
#      'lng': -84.51869040087105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.102058864478316,
#        'lng': -84.51869040087105}],
#      'distance': 87,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['105 E Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e692f23a80996c00616956d',
#     'name': 'Freight Kitchen & Tap',
#     'location': {'address': '251 E Main St',
#      'crossStreet': 'Towne Lake Parkway',
#      'lat': 34.100807765723786,
#      'lng': -84.51931609491892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100807765723786,
#        'lng': -84.51931609491892}],
#      'distance': 67,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['251 E Main St (Towne Lake Parkway)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '49157665'},
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4bc131bbf8219c746215b310',
#     'name': 'Woodstock First UMC',
#     'location': {'address': 'Main street',
#      'lat': 34.10105,
#      'lng': -84.52005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10105,
#        'lng': -84.52005}],
#      'distance': 86,
#      'cc': 'US',
#      'city': 'Cherokee',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Main street', 'Cherokee, GA', 'United States']},
#     'categories': [],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '581be2d503fcb4100cc69b1a',
#     'name': 'Sojourn Community Church',
#     'location': {'address': '8534 Main St',
#      'lat': 34.10178766,
#      'lng': -84.51980487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10178766,
#        'lng': -84.51980487}],
#      'distance': 68,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8534 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '5a80acf4e1791001a218907a',
#     'name': 'Partners II Pizza',
#     'location': {'address': '8600 Main St',
#      'lat': 34.100931,
#      'lng': -84.519577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100931,
#        'lng': -84.519577}],
#      'distance': 62,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8600 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1134363',
#      'url': 'https://www.grubhub.com/restaurant/partners-ii-pizza-8600-main-st-woodstock/1134363?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1134363',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f92da58e4b03828fd558c78',
#     'name': 'Antiques By Samson And Delilah',
#     'location': {'lat': 34.101241,
#      'lng': -84.519547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101241,
#        'lng': -84.519547}],
#      'distance': 35,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e1f3b42887799f23ff6bc13',
#     'name': 'IPPS',
#     'location': {'address': '8496 Main St',
#      'lat': 34.10225290777695,
#      'lng': -84.51934354513877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10225290777695,
#        'lng': -84.51934354513877}],
#      'distance': 94,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8496 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4d0f86a771e8a1cdac357bbd',
#     'name': "Val's Happy Shack",
#     'location': {'address': '8654 Main St',
#      'lat': 34.10027396524368,
#      'lng': -84.51993787437345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10027396524368,
#        'lng': -84.51993787437345}],
#      'distance': 142,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8654 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b845522f964a5203f2f31e3',
#     'name': "Out Spokin' Bicycles",
#     'location': {'address': '8594 Main St',
#      'lat': 34.10098749893729,
#      'lng': -84.51976246976366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10098749893729,
#        'lng': -84.51976246976366}],
#      'distance': 68,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8594 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115951735',
#       'name': 'Bike Shop',
#       'pluralName': 'Bike Shops',
#       'shortName': 'Bike Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '52756a5611d262de749ba4b1',
#     'name': 'Leaning Ladder',
#     'location': {'lat': 34.10194559580221,
#      'lng': -84.51830449996422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10194559580221,
#        'lng': -84.51830449996422}],
#      'distance': 103,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14b941735',
#       'name': 'Winery',
#       'pluralName': 'Wineries',
#       'shortName': 'Winery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e0e7368e4cd27fc7d30468b',
#     'name': 'Seven Arrows American Indian Art & Gifts',
#     'location': {'address': '8582 Main St',
#      'lat': 34.10128103,
#      'lng': -84.51952187,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10128103,
#        'lng': -84.51952187}],
#      'distance': 31,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8582 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '53d0530c498ea42202e0c1d6',
#     'name': 'NeoMed',
#     'location': {'address': '100 Londonderry Ct Ste 112',
#      'lat': 34.10149,
#      'lng': -84.51938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10149,
#        'lng': -84.51938}],
#      'distance': 17,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['100 Londonderry Ct Ste 112',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '561c6c68498e249eafdcd045',
#     'name': 'Truck & Tap',
#     'location': {'address': '8640 Main St',
#      'lat': 34.10034299588607,
#      'lng': -84.51990778367802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10034299588607,
#        'lng': -84.51990778367802}],
#      'distance': 134,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8640 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b3bc7e8f964a5200d7b25e3',
#     'name': 'Salon Vanessa',
#     'location': {'address': '8516 Main St',
#      'lat': 34.10193409141072,
#      'lng': -84.51951089405463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10193409141072,
#        'lng': -84.51951089405463}],
#      'distance': 64,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8516 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '53d951a2498e97eab69f1c23',
#     'name': "Brooklynn's",
#     'location': {'address': '500 Chambers St.',
#      'crossStreet': 'Wheeler Street',
#      'lat': 34.10008277794666,
#      'lng': -84.51887369155884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10008277794666,
#        'lng': -84.51887369155884}],
#      'distance': 151,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['500 Chambers St. (Wheeler Street)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '91905058'},
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '5c12924d625a66002c6c6415',
#     'name': 'Dominic’s NY Pizza',
#     'location': {'lat': 34.100212,
#      'lng': -84.520036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100212,
#        'lng': -84.520036}],
#      'distance': 153,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '5d1105703e8ac4002d5bed89',
#     'name': 'Brainfoods',
#     'location': {'lat': 34.100373,
#      'lng': -84.520214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100373,
#        'lng': -84.520214}],
#      'distance': 147,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4d5c71af5d153704e4b072e7',
#     'name': 'Elm Street Cultural Arts Village',
#     'location': {'address': '8534 Main St',
#      'lat': 34.101879747345876,
#      'lng': -84.52005461530234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101879747345876,
#        'lng': -84.52005461530234}],
#      'distance': 93,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8534 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d137941735',
#       'name': 'Theater',
#       'pluralName': 'Theaters',
#       'shortName': 'Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4c388ea093db0f47ffba2192',
#     'name': 'Main Street Woodstock Farmers Market',
#     'location': {'lat': 34.10057974003562,
#      'lng': -84.52086952507477,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10057974003562,
#        'lng': -84.52086952507477}],
#      'distance': 178,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '569ccdd5498edb460ff420a0',
#     'name': 'Plae Hard',
#     'location': {'lat': 34.10062685182311,
#      'lng': -84.52025020721045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10062685182311,
#        'lng': -84.52025020721045}],
#      'distance': 129,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4ed674ae2c5b3d826ebace86',
#     'name': 'The Playground at City Center',
#     'location': {'address': 'Adjacent To The Chambers At City Center',
#      'lat': 34.10139469810043,
#      'lng': -84.51974330553006,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10139469810043,
#        'lng': -84.51974330553006}],
#      'distance': 48,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Adjacent To The Chambers At City Center',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7941735',
#       'name': 'Playground',
#       'pluralName': 'Playgrounds',
#       'shortName': 'Playground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4d602a089f67f04d9f9075fb',
#     'name': 'Blue Frog Imports',
#     'location': {'address': '8608 Main St',
#      'lat': 34.10067677078471,
#      'lng': -84.51970949422261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10067677078471,
#        'lng': -84.51970949422261}],
#      'distance': 93,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8608 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4ed137b9b634dd29927ef0b7',
#     'name': 'The Wright Stuff Collectibles',
#     'location': {'address': '8646 Main St',
#      'lat': 34.10016399577493,
#      'lng': -84.51983546980004,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10016399577493,
#        'lng': -84.51983546980004}],
#      'distance': 150,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8646 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e57c968aeb7eff130d0854e',
#     'name': 'Natural Strides',
#     'location': {'address': '8636 Main St',
#      'lat': 34.10027215438052,
#      'lng': -84.51979962815682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10027215438052,
#        'lng': -84.51979962815682}],
#      'distance': 137,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8636 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d107951735',
#       'name': 'Shoe Store',
#       'pluralName': 'Shoe Stores',
#       'shortName': 'Shoes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4bbcd9a28ec3d13a88521b28',
#     'name': 'Woodstock Pharmacy',
#     'location': {'address': '8612 Main St',
#      'lat': 34.10059645241452,
#      'lng': -84.519682940493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10059645241452,
#        'lng': -84.519682940493}],
#      'distance': 100,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8612 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '58ec154a18384c12203ec7f1',
#     'name': 'Gyro Chef Mediterranean',
#     'location': {'lat': 34.10031247769499,
#      'lng': -84.52012732235967,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10031247769499,
#        'lng': -84.52012732235967}],
#      'distance': 148,
#      'postalCode': '30324',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Atlanta, GA 30324', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f86f7ebe4b0270511557731',
#     'name': 'Cupcakelicious LLC',
#     'location': {'address': '8654 Main St',
#      'lat': 34.10000892010498,
#      'lng': -84.51968460987202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10000892010498,
#        'lng': -84.51968460987202}],
#      'distance': 161,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8654 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1bc941735',
#       'name': 'Cupcake Shop',
#       'pluralName': 'Cupcake Shops',
#       'shortName': 'Cupcakes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4cba2a21bac93704c3cee97c',
#     'name': 'Woodstock Memorial',
#     'location': {'lat': 34.101383255382956,
#      'lng': -84.51764396878181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101383255382956,
#        'lng': -84.51764396878181}],
#      'distance': 145,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '58001ab038fa3dc50cdfb5b3',
#     'name': 'Sweet River Rough River Of Woodstock',
#     'location': {'address': '8636 Main St',
#      'lat': 34.10036,
#      'lng': -84.519966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10036,
#        'lng': -84.519966}],
#      'distance': 135,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8636 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b60984bf964a52050ef29e3',
#     'name': 'Landmark Commercial Realty',
#     'location': {'address': '8604 Main St',
#      'lat': 34.101295,
#      'lng': -84.519279,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101295,
#        'lng': -84.519279}],
#      'distance': 14,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8604 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f5a6b4ce4b09f2e904fe1de',
#     'name': 'Dress Up Boutique',
#     'location': {'address': 'Main Street',
#      'lat': 34.10031881731543,
#      'lng': -84.51919324269574,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10031881731543,
#        'lng': -84.51919324269574}],
#      'distance': 121,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Main Street', 'Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b9199dff964a520e5c833e3',
#     'name': "Dean's Store",
#     'location': {'address': '8588 Main St',
#      'lat': 34.101059441881276,
#      'lng': -84.51963578036411,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101059441881276,
#        'lng': -84.51963578036411}],
#      'distance': 54,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8588 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'shortName': 'Thrift / Vintage',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '57ffbdf238faa206848d3218',
#     'name': 'Southern Local',
#     'location': {'lat': 34.099903,
#      'lng': -84.52,
#      'labeledLatLngs': [{'label': 'display', 'lat': 34.099903, 'lng': -84.52}],
#      'distance': 182,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b7b51baf964a520245e2fe3',
#     'name': 'Foxtale Book Shoppe',
#     'location': {'address': '105 E Main St',
#      'lat': 34.102019467422366,
#      'lng': -84.51814928608407,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.102019467422366,
#        'lng': -84.51814928608407}],
#      'distance': 119,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['105 E Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '564500b7498edf3cd0e13bf9',
#     'name': 'Farmers Insurance',
#     'location': {'address': '8720 Main St',
#      'lat': 34.10039563,
#      'lng': -84.51984483,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10039563,
#        'lng': -84.51984483}],
#      'distance': 126,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8720 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f1',
#       'name': 'Insurance Office',
#       'pluralName': 'Insurance Offices',
#       'shortName': 'Insurance Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4b2cfb29f964a520becb24e3',
#     'name': 'Carney Studio',
#     'location': {'address': '105 E Main St Ste 146',
#      'lat': 34.10088121891022,
#      'lng': -84.51934576034546,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10088121891022,
#        'lng': -84.51934576034546}],
#      'distance': 60,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['105 E Main St Ste 146',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '56452883498ed0ce5c0e05bd',
#     'name': 'Metamodern Music',
#     'location': {'lat': 34.100891,
#      'lng': -84.519798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100891,
#        'lng': -84.519798}],
#      'distance': 78,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe941735',
#       'name': 'Music Store',
#       'pluralName': 'Music Stores',
#       'shortName': 'Music Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '52910ad611d2654437baa30d',
#     'name': 'Fashion Cupcake',
#     'location': {'lat': 34.10032368579755,
#      'lng': -84.51934392534174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10032368579755,
#        'lng': -84.51934392534174}],
#      'distance': 121,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4bce1c2ec564ef3b33adedf0',
#     'name': 'Summers Barber Shop',
#     'location': {'address': '8640 Main St',
#      'crossStreet': 'Elm St. Across from old Train Depot',
#      'lat': 34.100351,
#      'lng': -84.519762,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100351,
#        'lng': -84.519762}],
#      'distance': 128,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8640 Main St (Elm St. Across from old Train Depot)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f22a9afe4b0dc27b78e9fb3',
#     'name': 'Woodstock Morning Buzz',
#     'location': {'address': '8534 Main St',
#      'lat': 34.10175670194223,
#      'lng': -84.51972794480422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10175670194223,
#        'lng': -84.51972794480422}],
#      'distance': 60,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8534 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d129941735',
#       'name': 'City Hall',
#       'pluralName': 'City Halls',
#       'shortName': 'City Hall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/cityhall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e482b1618a8f9804ce06ad9',
#     'name': 'Latimer Hall',
#     'location': {'lat': 34.10124893026305,
#      'lng': -84.52022460622125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10124893026305,
#        'lng': -84.52022460622125}],
#      'distance': 94,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4cb63ba655af224b7065987e',
#     'name': 'Ann Litrel Art',
#     'location': {'address': '8594 Main St',
#      'lat': 34.100921,
#      'lng': -84.519447,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100921,
#        'lng': -84.519447}],
#      'distance': 58,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8594 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f45588be4b04ef91c679115',
#     'name': 'Realtor in Location',
#     'location': {'lat': 34.1014287106486,
#      'lng': -84.51921701431274,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.1014287106486,
#        'lng': -84.51921701431274}],
#      'distance': 1,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '57fc046ecd10f334dbad01da',
#     'name': 'Sweet River Rough River Of Woodstock',
#     'location': {'lat': 34.10036,
#      'lng': -84.519966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10036,
#        'lng': -84.519966}],
#      'distance': 135,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4c82442151ada1cddd5d1a10',
#     'name': 'New Image Hair Salon',
#     'location': {'address': '8590 Main St',
#      'crossStreet': 'Towne Lake Pkwy',
#      'lat': 34.101326810798355,
#      'lng': -84.5196613816121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101326810798355,
#        'lng': -84.5196613816121}],
#      'distance': 41,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8590 Main St (Towne Lake Pkwy)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '59d46afe5ba0465b5c7f5701',
#     'name': 'GI Specialists of Georgia',
#     'location': {'address': '118 Mill St Ste 110',
#      'lat': 34.10137540679028,
#      'lng': -84.5194101333618,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10137540679028,
#        'lng': -84.5194101333618}],
#      'distance': 18,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['118 Mill St Ste 110',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
# ...
#      'formattedAddress': ['Main St (Towne Lake Pkwy)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#       'name': 'Intersection',
#       'pluralName': 'Intersections',
#       'shortName': 'Intersection',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4bae5668f964a5209aa43be3',
#     'name': 'Pennybag Emporium',
#     'location': {'lat': 34.100957,
#      'lng': -84.519687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100957,
#        'lng': -84.519687}],
#      'distance': 66,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4c07c977221620a1b051f775',
#     'name': 'Roomscapes Gallery',
#     'location': {'lat': 34.100756,
#      'lng': -84.519212,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100756,
#        'lng': -84.519212}],
#      'distance': 72,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4d08dad9790fa093cf9fc573',
#     'name': 'Diversified Mortgage Solutions',
#     'location': {'address': '8582 Main St',
#      'lat': 34.101192355155945,
#      'lng': -84.5196944475174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101192355155945,
#        'lng': -84.5196944475174}],
#      'distance': 50,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8582 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '50c0b718e4b08c1f64385538',
#     'name': 'first Woodstock United methodist Church Thrift Store',
#     'location': {'lat': 34.1009407043457,
#      'lng': -84.52024841308594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.1009407043457,
#        'lng': -84.52024841308594}],
#      'distance': 108,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'shortName': 'Thrift / Vintage',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '51c0aaf0498ecb98ec5f2e05',
#     'name': 'Woodstock Pharmacy',
#     'location': {'lat': 34.100854,
#      'lng': -84.520349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.100854,
#        'lng': -84.520349}],
#      'distance': 121,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4c405da7520fa5935de5c7ac',
#     'name': 'Kara Christian Styling Stydio',
#     'location': {'address': '105 E Main St',
#      'lat': 34.1019927159687,
#      'lng': -84.51822257402283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.1019927159687,
#        'lng': -84.51822257402283}],
#      'distance': 112,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['105 E Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4fd128f9e4b0b895948a0966',
#     'name': 'Gin Miller Fitness',
#     'location': {'address': '8650 Main St',
#      'lat': 34.10014887802261,
#      'lng': -84.5199429945974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10014887802261,
#        'lng': -84.5199429945974}],
#      'distance': 155,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8650 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'shortName': 'Yoga Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '5050c5a6e4b030bfc6e8d67b',
#     'name': 'Threads',
#     'location': {'address': '500 Chambers Street',
#      'crossStreet': 'Main St',
#      'lat': 34.10030383325957,
#      'lng': -84.51910327185495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10030383325957,
#        'lng': -84.51910327185495}],
#      'distance': 123,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['500 Chambers Street (Main St)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4c4da9cefb742d7f0d211b2d',
#     'name': 'Cherokee Ledger-News',
#     'location': {'address': '103 E Main St',
#      'lat': 34.102475248120584,
#      'lng': -84.51867828560981,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.102475248120584,
#        'lng': -84.51867828560981}],
#      'distance': 128,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['103 E Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4bb8f8bf98c7ef3bcfa33102',
#     'name': 'Darren Drevik Photography',
#     'location': {'address': '116 Hubbard Rd',
#      'crossStreet': 'Wheeler Street',
#      'lat': 34.10027004784212,
#      'lng': -84.51961529935761,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10027004784212,
#        'lng': -84.51961529935761}],
#      'distance': 132,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['116 Hubbard Rd (Wheeler Street)',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e0b1e4722713e13018ede79',
#     'name': 'Zumba at Latimer Hall',
#     'location': {'lat': 34.101052,
#      'lng': -84.520237,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101052,
#        'lng': -84.520237}],
#      'distance': 101,
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA', 'United States']},
#     'categories': [],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f328aace4b092d58cc77a7e',
#     'name': 'Dr. Hurter/ Mrs. Hensons Class',
#     'location': {'address': 'Uhhh',
#      'crossStreet': 'Idk',
#      'lat': 34.1014,
#      'lng': -84.5193,
#      'labeledLatLngs': [{'label': 'display', 'lat': 34.1014, 'lng': -84.5193}],
#      'distance': 7,
#      'postalCode': '30114',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Uhhh (Idk)',
#       'Woodstock, GA 30114',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '50297527e4b029a5bc950338',
#     'name': 'Bluefrog',
#     'location': {'address': '8608 Main St',
#      'lat': 34.10112676396213,
#      'lng': -84.51973306504661,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10112676396213,
#        'lng': -84.51973306504661}],
#      'distance': 56,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['8608 Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'shortName': 'Thrift / Vintage',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4f1f41dae4b046c2fefffa6c',
#     'name': "Campo's Garage",
#     'location': {'lat': 34.101487,
#      'lng': -84.519375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101487,
#        'lng': -84.519375}],
#      'distance': 16,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Woodstock, GA 30188', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'shortName': 'Sports Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4ea650e6d5fbffc9192bfc75',
#     'name': 'Matthew Druin Photography',
#     'location': {'address': '105 E Main St',
#      'lat': 34.09815588834858,
#      'lng': -84.51461862213088,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.09815588834858,
#        'lng': -84.51461862213088}],
#      'distance': 557,
#      'postalCode': '30188',
#      'cc': 'US',
#      'city': 'Woodstock',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['105 E Main St',
#       'Woodstock, GA 30188',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4e1b0486d22d8a338fe93ef7',
#     'name': 'Health Dept',
#     'location': {'lat': 34.101512042562696,
#      'lng': -84.51931832395422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.101512042562696,
#        'lng': -84.51931832395422}],
#      'distance': 14,
#      'cc': 'US',
#      'state': 'Georgia',
#      'country': 'United States',
#      'formattedAddress': ['Georgia', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '553fbd6e498e1886320b6734',
#     'name': 'Angelfire7 BBQ',
#     'location': {'lat': 34.10035253207514,
#      'lng': -84.51980986862857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10035253207514,
#        'lng': -84.51980986862857}],
#      'distance': 129,
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Atlanta, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '4c9e2adc03133704f40566d5',
#     'name': 'The Pickle',
#     'location': {'address': '250 14th St NW',
#      'lat': 34.10031556288129,
#      'lng': -84.51995323504393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10031556288129,
#        'lng': -84.51995323504393}],
#      'distance': 139,
#      'postalCode': '30318',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['250 14th St NW',
#       'Atlanta, GA 30318',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False},
#    {'id': '579cba59498e975fa65c315d',
#     'name': 'deep south biscuit company',
#     'location': {'lat': 34.10039245294302,
#      'lng': -84.52021948602206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10039245294302,
#        'lng': -84.52021948602206}],
#      'distance': 146,
#      'postalCode': '30309',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Atlanta, GA 30309', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566934251',
#     'hasPerk': False}],
#   'confident': True}}

# %%
# assign relevant part of JSON to venues
wvenues = wresults['response']['venues']

# tranform venues into a dataframe
wdataframe = json_normalize(wvenues)
wdataframe.head()
# Out:
#                          id                        name  \
# 0  50b3ac3fe4b0f78dc10d26e6          Main St. Woodstock
# 1  4bb498b5a187ef3b1dc84942  Main Street Woodstock Inc.
# 2  530a5c53498e3916df663037          Downtown Woodstock
# 3  593f1b4c09e2831c1992e06e            Rootstock & Vine
# 4  4b2fe403f964a5200ff224e3         Woodstock City Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f6931735', 'name': 'G...  v-1566934251    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1566934251    False
# 2  [{'id': '4bf58dd8d48988d11a941735', 'name': 'O...  v-1566934251    False
# 3  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1566934251    False
# 4  [{'id': '4bf58dd8d48988d164941735', 'name': 'P...  v-1566934251    False
#
#    location.lat  location.lng  \
# 0     34.101309    -84.519457
# 1     34.100559    -84.519810
# 2     34.101465    -84.519262
# 3     34.101276    -84.519561
# 4     34.101692    -84.518653
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 34.10130943021684...                 24
# 1  [{'label': 'display', 'lat': 34.10055915034406...                109
# 2  [{'label': 'display', 'lat': 34.10146492038731...                  7
# 3  [{'label': 'display', 'lat': 34.10127615264531...                 34
# 4  [{'label': 'display', 'lat': 34.10169208424052...                 60
#
#   location.postalCode location.cc location.city location.state  \
# 0               30188          US     Woodstock             GA
# 1               30188          US     Woodstock             GA
# 2                 NaN          US     Woodstock             GA
# 3               30188          US     Woodstock             GA
# 4               30188          US     Woodstock             GA
#
#   location.country                          location.formattedAddress  \
# 0    United States               [Woodstock, GA 30188, United States]
# 1    United States  [8632 Main St, Woodstock, GA 30188, United Sta...
# 2    United States                     [Woodstock, GA, United States]
# 3    United States  [8558 Main St (Townelake Parkway), Woodstock, ...
# 4    United States  [101 Arnold Mill Rd (Main St), Woodstock, GA 3...
#
#      location.address location.crossStreet venuePage.id delivery.id  \
# 0                 NaN                  NaN          NaN         NaN
# 1        8632 Main St                  NaN          NaN         NaN
# 2                 NaN                  NaN          NaN         NaN
# 3        8558 Main St    Townelake Parkway    478525471         NaN
# 4  101 Arnold Mill Rd              Main St          NaN         NaN
#
#   delivery.url delivery.provider.name delivery.provider.icon.prefix  \
# 0          NaN                    NaN                           NaN
# 1          NaN                    NaN                           NaN
# 2          NaN                    NaN                           NaN
# 3          NaN                    NaN                           NaN
# 4          NaN                    NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.icon.name
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
wfiltered_columns = ['name', 'categories'] + [col for col in wdataframe.columns if col.startswith('location.')] + ['id']
wdataframe_filtered = wdataframe.loc[:, wfiltered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
wdataframe_filtered['categories'] = wdataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
wdataframe_filtered.columns = [column.split('.')[-1] for column in wdataframe_filtered.columns]

wdataframe_filtered
# Out:
#                                                  name              categories  \
# 0                                  Main St. Woodstock          General Travel
# 1                          Main Street Woodstock Inc.                  Office
# 2                                  Downtown Woodstock         Other Nightlife
# 3                                    Rootstock & Vine                Wine Bar
# 4                                 Woodstock City Park                   Plaza
# 5                               Atlantic Gifts & More               Gift Shop
# 6                              Woodstock Amphitheater            Amphitheater
# 7                                 Morgan Ace Hardware          Hardware Store
# 8                               Holly Springs Jewelry           Jewelry Store
# 9                         The Chambers At City Center               City Hall
# 10                                         Vingenzo's      Italian Restaurant
# 11                              Freight Kitchen & Tap               Gastropub
# 12                                Woodstock First UMC                    None
# 13                           Sojourn Community Church                  Church
# 14                                  Partners II Pizza             Pizza Place
# 15                     Antiques By Samson And Delilah            Antique Shop
# 16                                               IPPS      Italian Restaurant
# 17                                  Val's Happy Shack                Boutique
# 18                               Out Spokin' Bicycles               Bike Shop
# 19                                     Leaning Ladder                  Winery
# 20           Seven Arrows American Indian Art & Gifts               Gift Shop
# 21                                             NeoMed          Medical Center
# 22                                        Truck & Tap                     Bar
# 23                                      Salon Vanessa      Salon / Barbershop
# 24                                        Brooklynn's           Women's Store
# 25                                 Dominic’s NY Pizza              Food Truck
# 26                                         Brainfoods              Food Truck
# 27                   Elm Street Cultural Arts Village                 Theater
# 28               Main Street Woodstock Farmers Market          Farmers Market
# 29                                          Plae Hard    Gym / Fitness Center
# 30                      The Playground at City Center              Playground
# 31                                  Blue Frog Imports     Arts & Crafts Store
# 32                      The Wright Stuff Collectibles            Antique Shop
# 33                                    Natural Strides              Shoe Store
# 34                                 Woodstock Pharmacy                Pharmacy
# 35                            Gyro Chef Mediterranean              Food Truck
# 36                                 Cupcakelicious LLC            Cupcake Shop
# 37                                 Woodstock Memorial                    Park
# 38               Sweet River Rough River Of Woodstock          Clothing Store
# 39                         Landmark Commercial Realty                Building
# 40                                  Dress Up Boutique                Boutique
# 41                                       Dean's Store  Thrift / Vintage Store
# 42                                     Southern Local          Clothing Store
# 43                                Foxtale Book Shoppe               Bookstore
# 44                                  Farmers Insurance        Insurance Office
# 45                                      Carney Studio                    None
# 46                                   Metamodern Music             Music Store
# 47                                    Fashion Cupcake                Boutique
# 48                                Summers Barber Shop      Salon / Barbershop
# 49                             Woodstock Morning Buzz               City Hall
# 50                                       Latimer Hall             Event Space
# 51                                     Ann Litrel Art             Art Gallery
# 52                                Realtor in Location                Building
# 53               Sweet River Rough River Of Woodstock          Clothing Store
# 54                               New Image Hair Salon      Salon / Barbershop
# 55                          GI Specialists of Georgia         Doctor's Office
# 56                                  BeautyMark Studio              Nail Salon
# 57                                 Jacqueline's Salon                    None
# 58                              Sip And Shop Boutique               Gift Shop
# 59                                     Salon Bastille                    None
# 60                               The Funky Paintbrush             Art Gallery
# 61                 legacy partners financial planning                Building
# 62                                               Park  Furniture / Home Store
# 63                                            Dismero                Boutique
# 64                                         Alex N Sis              Kids Store
# 65                                       Honey Butter           Women's Store
# 66                                     LKT Sports Art     Sporting Goods Shop
# 67                                      Woodstock DDA                  Office
# 68                                   Collective Co-op      Miscellaneous Shop
# 69         Main St & Towne Lake Pkwy / Arnold Mill Rd            Intersection
# 70                                  Pennybag Emporium            Antique Shop
# 71                                 Roomscapes Gallery             Art Gallery
# 72                     Diversified Mortgage Solutions                    Bank
# 73  first Woodstock United methodist Church Thrift...  Thrift / Vintage Store
# 74                                 Woodstock Pharmacy          Medical Center
# 75                      Kara Christian Styling Stydio      Salon / Barbershop
# 76                                 Gin Miller Fitness             Yoga Studio
# 77                                            Threads          Clothing Store
# 78                               Cherokee Ledger-News                    None
# 79                          Darren Drevik Photography                  Office
# 80                              Zumba at Latimer Hall                    None
# 81                     Dr. Hurter/ Mrs. Hensons Class             High School
# 82                                           Bluefrog  Thrift / Vintage Store
# 83                                     Campo's Garage              Sports Bar
# 84                          Matthew Druin Photography                  Office
# 85                                        Health Dept         Doctor's Office
# 86                                     Angelfire7 BBQ              Food Truck
# 87                                         The Pickle              Food Truck
# 88                         deep south biscuit company              Food Truck
#
#           lat        lng                                     labeledLatLngs  \
# 0   34.101309 -84.519457  [{'label': 'display', 'lat': 34.10130943021684...
# 1   34.100559 -84.519810  [{'label': 'display', 'lat': 34.10055915034406...
# 2   34.101465 -84.519262  [{'label': 'display', 'lat': 34.10146492038731...
# 3   34.101276 -84.519561  [{'label': 'display', 'lat': 34.10127615264531...
# 4   34.101692 -84.518653  [{'label': 'display', 'lat': 34.10169208424052...
# 5   34.101490 -84.519380  [{'label': 'display', 'lat': 34.10149, 'lng': ...
# 6   34.101739 -84.518101  [{'label': 'display', 'lat': 34.101739, 'lng':...
# 7   34.100145 -84.518574  [{'label': 'display', 'lat': 34.1001449, 'lng'...
# 8   34.100878 -84.518831  [{'label': 'display', 'lat': 34.10087790249361...
# 9   34.101763 -84.519698  [{'label': 'display', 'lat': 34.10176346157377...
# 10  34.102059 -84.518690  [{'label': 'display', 'lat': 34.10205886447831...
# 11  34.100808 -84.519316  [{'label': 'display', 'lat': 34.10080776572378...
# 12  34.101050 -84.520050  [{'label': 'display', 'lat': 34.10105, 'lng': ...
# 13  34.101788 -84.519805  [{'label': 'display', 'lat': 34.10178766, 'lng...
# 14  34.100931 -84.519577  [{'label': 'display', 'lat': 34.100931, 'lng':...
# 15  34.101241 -84.519547  [{'label': 'display', 'lat': 34.101241, 'lng':...
# 16  34.102253 -84.519344  [{'label': 'display', 'lat': 34.10225290777695...
# 17  34.100274 -84.519938  [{'label': 'display', 'lat': 34.10027396524368...
# 18  34.100987 -84.519762  [{'label': 'display', 'lat': 34.10098749893729...
# 19  34.101946 -84.518304  [{'label': 'display', 'lat': 34.10194559580221...
# 20  34.101281 -84.519522  [{'label': 'display', 'lat': 34.10128103, 'lng...
# 21  34.101490 -84.519380  [{'label': 'display', 'lat': 34.10149, 'lng': ...
# 22  34.100343 -84.519908  [{'label': 'display', 'lat': 34.10034299588607...
# 23  34.101934 -84.519511  [{'label': 'display', 'lat': 34.10193409141072...
# 24  34.100083 -84.518874  [{'label': 'display', 'lat': 34.10008277794666...
# 25  34.100212 -84.520036  [{'label': 'display', 'lat': 34.100212, 'lng':...
# 26  34.100373 -84.520214  [{'label': 'display', 'lat': 34.100373, 'lng':...
# 27  34.101880 -84.520055  [{'label': 'display', 'lat': 34.10187974734587...
# 28  34.100580 -84.520870  [{'label': 'display', 'lat': 34.10057974003562...
# 29  34.100627 -84.520250  [{'label': 'display', 'lat': 34.10062685182311...
# 30  34.101395 -84.519743  [{'label': 'display', 'lat': 34.10139469810043...
# 31  34.100677 -84.519709  [{'label': 'display', 'lat': 34.10067677078471...
# 32  34.100164 -84.519835  [{'label': 'display', 'lat': 34.10016399577493...
# 33  34.100272 -84.519800  [{'label': 'display', 'lat': 34.10027215438052...
# 34  34.100596 -84.519683  [{'label': 'display', 'lat': 34.10059645241452...
# 35  34.100312 -84.520127  [{'label': 'display', 'lat': 34.10031247769499...
# 36  34.100009 -84.519685  [{'label': 'display', 'lat': 34.10000892010498...
# 37  34.101383 -84.517644  [{'label': 'display', 'lat': 34.10138325538295...
# 38  34.100360 -84.519966  [{'label': 'display', 'lat': 34.10036, 'lng': ...
# 39  34.101295 -84.519279  [{'label': 'display', 'lat': 34.101295, 'lng':...
# 40  34.100319 -84.519193  [{'label': 'display', 'lat': 34.10031881731543...
# 41  34.101059 -84.519636  [{'label': 'display', 'lat': 34.10105944188127...
# 42  34.099903 -84.520000  [{'label': 'display', 'lat': 34.099903, 'lng':...
# 43  34.102019 -84.518149  [{'label': 'display', 'lat': 34.10201946742236...
# 44  34.100396 -84.519845  [{'label': 'display', 'lat': 34.10039563, 'lng...
# 45  34.100881 -84.519346  [{'label': 'display', 'lat': 34.10088121891022...
# 46  34.100891 -84.519798  [{'label': 'display', 'lat': 34.100891, 'lng':...
# 47  34.100324 -84.519344  [{'label': 'display', 'lat': 34.10032368579755...
# 48  34.100351 -84.519762  [{'label': 'display', 'lat': 34.100351, 'lng':...
# 49  34.101757 -84.519728  [{'label': 'display', 'lat': 34.10175670194223...
# 50  34.101249 -84.520225  [{'label': 'display', 'lat': 34.10124893026305...
# 51  34.100921 -84.519447  [{'label': 'display', 'lat': 34.100921, 'lng':...
# 52  34.101429 -84.519217  [{'label': 'display', 'lat': 34.1014287106486,...
# 53  34.100360 -84.519966  [{'label': 'display', 'lat': 34.10036, 'lng': ...
# 54  34.101327 -84.519661  [{'label': 'display', 'lat': 34.10132681079835...
# 55  34.101375 -84.519410  [{'label': 'display', 'lat': 34.10137540679028...
# 56  34.100360 -84.519740  [{'label': 'display', 'lat': 34.10036, 'lng': ...
# 57  34.101193 -84.517831  [{'label': 'display', 'lat': 34.10119294999251...
# 58  34.101001 -84.519952  [{'label': 'display', 'lat': 34.101001, 'lng':...
# 59  34.100144 -84.519979  [{'label': 'display', 'lat': 34.10014431695725...
# 60  34.100242 -84.519817  [{'label': 'display', 'lat': 34.10024172635376...
# 61  34.100620 -84.520440  [{'label': 'display', 'lat': 34.10062, 'lng': ...
# 62  34.100393 -84.519000  [{'label': 'display', 'lat': 34.100393, 'lng':...
# 63  34.100042 -84.519400  [{'label': 'display', 'lat': 34.10004239168298...
# 64  34.100055 -84.519027  [{'label': 'display', 'lat': 34.10005465, 'lng...
# 65  34.100244 -84.519231  [{'label': 'display', 'lat': 34.10024423333333...
# 66  34.100525 -84.519747  [{'label': 'display', 'lat': 34.10052458, 'lng...
# 67  34.100594 -84.520390  [{'label': 'display', 'lat': 34.100594, 'lng':...
# 68  34.101962 -84.518315  [{'label': 'display', 'lat': 34.101962, 'lng':...
# 69  34.101313 -84.519392  [{'label': 'display', 'lat': 34.10131321891314...
# 70  34.100957 -84.519687  [{'label': 'display', 'lat': 34.100957, 'lng':...
# 71  34.100756 -84.519212  [{'label': 'display', 'lat': 34.100756, 'lng':...
# 72  34.101192 -84.519694  [{'label': 'display', 'lat': 34.10119235515594...
# 73  34.100941 -84.520248  [{'label': 'display', 'lat': 34.1009407043457,...
# 74  34.100854 -84.520349  [{'label': 'display', 'lat': 34.100854, 'lng':...
# 75  34.101993 -84.518223  [{'label': 'display', 'lat': 34.1019927159687,...
# 76  34.100149 -84.519943  [{'label': 'display', 'lat': 34.10014887802261...
# 77  34.100304 -84.519103  [{'label': 'display', 'lat': 34.10030383325957...
# 78  34.102475 -84.518678  [{'label': 'display', 'lat': 34.10247524812058...
# 79  34.100270 -84.519615  [{'label': 'display', 'lat': 34.10027004784212...
# 80  34.101052 -84.520237  [{'label': 'display', 'lat': 34.101052, 'lng':...
# 81  34.101400 -84.519300  [{'label': 'display', 'lat': 34.1014, 'lng': -...
# 82  34.101127 -84.519733  [{'label': 'display', 'lat': 34.10112676396213...
# 83  34.101487 -84.519375  [{'label': 'display', 'lat': 34.101487, 'lng':...
# 84  34.098156 -84.514619  [{'label': 'display', 'lat': 34.09815588834858...
# 85  34.101512 -84.519318  [{'label': 'display', 'lat': 34.10151204256269...
# 86  34.100353 -84.519810  [{'label': 'display', 'lat': 34.10035253207514...
# 87  34.100316 -84.519953  [{'label': 'display', 'lat': 34.10031556288129...
# 88  34.100392 -84.520219  [{'label': 'display', 'lat': 34.10039245294302...
#
#     distance postalCode  cc       city    state        country  \
# 0         24      30188  US  Woodstock       GA  United States
# 1        109      30188  US  Woodstock       GA  United States
# 2          7        NaN  US  Woodstock       GA  United States
# 3         34      30188  US  Woodstock       GA  United States
# 4         60      30188  US  Woodstock       GA  United States
# 5         17      30189  US  Woodstock       GA  United States
# 6        109      30188  US  Woodstock       GA  United States
# 7        152      30188  US  Woodstock       GA  United States
# 8         69      30188  US  Woodstock       GA  United States
# 9         59      30188  US  Woodstock       GA  United States
# 10        87      30188  US  Woodstock       GA  United States
# 11        67      30188  US  Woodstock       GA  United States
# 12        86        NaN  US   Cherokee       GA  United States
# 13        68      30188  US  Woodstock       GA  United States
# 14        62      30188  US  Woodstock       GA  United States
# 15        35      30188  US  Woodstock       GA  United States
# 16        94      30188  US  Woodstock       GA  United States
# 17       142      30188  US  Woodstock       GA  United States
# 18        68      30188  US  Woodstock       GA  United States
# 19       103        NaN  US  Woodstock       GA  United States
# 20        31      30188  US  Woodstock       GA  United States
# 21        17      30188  US  Woodstock       GA  United States
# 22       134      30188  US  Woodstock       GA  United States
# 23        64      30188  US  Woodstock       GA  United States
# 24       151      30188  US  Woodstock       GA  United States
# 25       153      30188  US  Woodstock       GA  United States
# 26       147      30188  US  Woodstock       GA  United States
# 27        93      30188  US  Woodstock       GA  United States
# 28       178      30188  US  Woodstock       GA  United States
# 29       129        NaN  US  Woodstock       GA  United States
# 30        48      30188  US  Woodstock       GA  United States
# 31        93      30188  US  Woodstock       GA  United States
# 32       150      30188  US  Woodstock       GA  United States
# 33       137      30188  US  Woodstock       GA  United States
# 34       100      30188  US  Woodstock       GA  United States
# 35       148      30324  US    Atlanta       GA  United States
# 36       161      30188  US  Woodstock       GA  United States
# 37       145      30188  US  Woodstock       GA  United States
# 38       135      30188  US  Woodstock       GA  United States
# 39        14      30188  US  Woodstock       GA  United States
# 40       121        NaN  US  Woodstock       GA  United States
# 41        54      30188  US  Woodstock       GA  United States
# 42       182      30188  US  Woodstock       GA  United States
# 43       119      30188  US  Woodstock       GA  United States
# 44       126      30188  US  Woodstock       GA  United States
# 45        60      30188  US  Woodstock       GA  United States
# 46        78        NaN  US  Woodstock       GA  United States
# 47       121        NaN  US  Woodstock       GA  United States
# 48       128      30188  US  Woodstock       GA  United States
# 49        60      30188  US  Woodstock       GA  United States
# 50        94        NaN  US  Woodstock       GA  United States
# 51        58      30188  US  Woodstock       GA  United States
# 52         1      30188  US  Woodstock       GA  United States
# 53       135        NaN  US  Woodstock       GA  United States
# 54        41      30188  US  Woodstock       GA  United States
# 55        18      30188  US  Woodstock       GA  United States
# 56       126      30188  US  Woodstock       GA  United States
# 57       130      30188  US  Woodstock       GA  United States
# 58        81      30188  US  Woodstock       GA  United States
# 59       157      30188  US  Woodstock       GA  United States
# 60       141      30188  US  Woodstock       GA  United States
# 61       142      30188  US  Woodstock       GA  United States
# 62       115      30188  US  Woodstock       GA  United States
# 63       153        NaN  US  Woodstock       GA  United States
# 64       152      30188  US  Woodstock       GA  United States
# 65       129      30188  US  Woodstock       GA  United States
# 66       110      30188  US  Woodstock       GA  United States
# 67       141      30188  US  Woodstock       GA  United States
# 68       103      30188  US  Woodstock       GA  United States
# 69        19      30188  US  Woodstock       GA  United States
# 70        66      30188  US  Woodstock       GA  United States
# 71        72      30188  US  Woodstock       GA  United States
# 72        50      30188  US  Woodstock       GA  United States
# 73       108      30188  US  Woodstock       GA  United States
# 74       121        NaN  US  Woodstock       GA  United States
# 75       112      30188  US  Woodstock       GA  United States
# 76       155      30188  US  Woodstock       GA  United States
# 77       123      30188  US  Woodstock       GA  United States
# 78       128      30188  US  Woodstock       GA  United States
# 79       132      30188  US  Woodstock       GA  United States
# 80       101        NaN  US  Woodstock       GA  United States
# 81         7      30114  US  Woodstock       GA  United States
# 82        56      30188  US  Woodstock       GA  United States
# 83        16      30188  US  Woodstock       GA  United States
# 84       557      30188  US  Woodstock       GA  United States
# 85        14        NaN  US        NaN  Georgia  United States
# 86       129        NaN  US    Atlanta       GA  United States
# 87       139      30318  US    Atlanta       GA  United States
# 88       146      30309  US    Atlanta       GA  United States
#
#                                      formattedAddress  \
# 0                [Woodstock, GA 30188, United States]
# 1   [8632 Main St, Woodstock, GA 30188, United Sta...
# 2                      [Woodstock, GA, United States]
# 3   [8558 Main St (Townelake Parkway), Woodstock, ...
# 4   [101 Arnold Mill Rd (Main St), Woodstock, GA 3...
# 5                [Woodstock, GA 30189, United States]
# 6                [Woodstock, GA 30188, United States]
# 7   [109 E Main St, Woodstock, GA 30188, United St...
# 8   [510 Chambers St (South Main St.), Woodstock, ...
# 9   [8534 Main St (Towne Lake Parkway), Woodstock,...
# 10  [105 E Main St, Woodstock, GA 30188, United St...
# 11  [251 E Main St (Towne Lake Parkway), Woodstock...
# 12         [Main street, Cherokee, GA, United States]
# 13  [8534 Main St, Woodstock, GA 30188, United Sta...
# 14  [8600 Main St, Woodstock, GA 30188, United Sta...
# 15               [Woodstock, GA 30188, United States]
# 16  [8496 Main St, Woodstock, GA 30188, United Sta...
# 17  [8654 Main St, Woodstock, GA 30188, United Sta...
# 18  [8594 Main St, Woodstock, GA 30188, United Sta...
# 19                     [Woodstock, GA, United States]
# 20  [8582 Main St, Woodstock, GA 30188, United Sta...
# 21  [100 Londonderry Ct Ste 112, Woodstock, GA 301...
# 22  [8640 Main St, Woodstock, GA 30188, United Sta...
# 23  [8516 Main St, Woodstock, GA 30188, United Sta...
# 24  [500 Chambers St. (Wheeler Street), Woodstock,...
# 25               [Woodstock, GA 30188, United States]
# 26               [Woodstock, GA 30188, United States]
# 27  [8534 Main St, Woodstock, GA 30188, United Sta...
# 28               [Woodstock, GA 30188, United States]
# 29                     [Woodstock, GA, United States]
# 30  [Adjacent To The Chambers At City Center, Wood...
# 31  [8608 Main St, Woodstock, GA 30188, United Sta...
# 32  [8646 Main St, Woodstock, GA 30188, United Sta...
# 33  [8636 Main St, Woodstock, GA 30188, United Sta...
# 34  [8612 Main St, Woodstock, GA 30188, United Sta...
# 35                 [Atlanta, GA 30324, United States]
# 36  [8654 Main St, Woodstock, GA 30188, United Sta...
# 37               [Woodstock, GA 30188, United States]
# 38  [8636 Main St, Woodstock, GA 30188, United Sta...
# 39  [8604 Main St, Woodstock, GA 30188, United Sta...
# 40        [Main Street, Woodstock, GA, United States]
# 41  [8588 Main St, Woodstock, GA 30188, United Sta...
# 42               [Woodstock, GA 30188, United States]
# 43  [105 E Main St, Woodstock, GA 30188, United St...
# 44  [8720 Main St, Woodstock, GA 30188, United Sta...
# 45  [105 E Main St Ste 146, Woodstock, GA 30188, U...
# 46                     [Woodstock, GA, United States]
# 47                     [Woodstock, GA, United States]
# 48  [8640 Main St (Elm St. Across from old Train D...
# 49  [8534 Main St, Woodstock, GA 30188, United Sta...
# 50                     [Woodstock, GA, United States]
# 51  [8594 Main St, Woodstock, GA 30188, United Sta...
# 52               [Woodstock, GA 30188, United States]
# 53                     [Woodstock, GA, United States]
# 54  [8590 Main St (Towne Lake Pkwy), Woodstock, GA...
# 55  [118 Mill St Ste 110, Woodstock, GA 30188, Uni...
# 56  [8720 Main St Ste 110, Woodstock, GA 30188, Un...
# 57  [102 Arnold Mill Rd, Woodstock, GA 30188, Unit...
# 58  [8608 Main St, Woodstock, GA 30188, United Sta...
# 59               [Woodstock, GA 30188, United States]
# 60  [8650 Main St, Woodstock, GA 30188, United Sta...
# 61  [123 Mill St, Woodstock, GA 30188, United States]
# 62               [Woodstock, GA 30188, United States]
# 63        [Main Street, Woodstock, GA, United States]
# 64  [470 Chambers St (Arnold Mill Road), Woodstock...
# 65  [490 Chambers St, Woodstock, GA 30188, United ...
# 66  [8634 Main St, Woodstock, GA 30188, United Sta...
# 67  [8632 Main St, Woodstock, GA 30188, United Sta...
# 68  [105 E Main St, Woodstock, GA 30188, United St...
# 69  [Main St (Towne Lake Pkwy), Woodstock, GA 3018...
# 70               [Woodstock, GA 30188, United States]
# 71               [Woodstock, GA 30188, United States]
# 72  [8582 Main St, Woodstock, GA 30188, United Sta...
# 73               [Woodstock, GA 30188, United States]
# 74                     [Woodstock, GA, United States]
# 75  [105 E Main St, Woodstock, GA 30188, United St...
# 76  [8650 Main St, Woodstock, GA 30188, United Sta...
# 77  [500 Chambers Street (Main St), Woodstock, GA ...
# 78  [103 E Main St, Woodstock, GA 30188, United St...
# 79  [116 Hubbard Rd (Wheeler Street), Woodstock, G...
# 80                     [Woodstock, GA, United States]
# 81   [Uhhh (Idk), Woodstock, GA 30114, United States]
# 82  [8608 Main St, Woodstock, GA 30188, United Sta...
# 83               [Woodstock, GA 30188, United States]
# 84  [105 E Main St, Woodstock, GA 30188, United St...
# 85                           [Georgia, United States]
# 86                       [Atlanta, GA, United States]
# 87  [250 14th St NW, Atlanta, GA 30318, United Sta...
# 88                 [Atlanta, GA 30309, United States]
#
#                                     address  \
# 0                                       NaN
# 1                              8632 Main St
# 2                                       NaN
# 3                              8558 Main St
# 4                        101 Arnold Mill Rd
# 5                                       NaN
# 6                                       NaN
# 7                             109 E Main St
# 8                           510 Chambers St
# 9                              8534 Main St
# 10                            105 E Main St
# 11                            251 E Main St
# 12                              Main street
# 13                             8534 Main St
# 14                             8600 Main St
# 15                                      NaN
# 16                             8496 Main St
# 17                             8654 Main St
# 18                             8594 Main St
# 19                                      NaN
# 20                             8582 Main St
# 21               100 Londonderry Ct Ste 112
# 22                             8640 Main St
# 23                             8516 Main St
# 24                         500 Chambers St.
# 25                                      NaN
# 26                                      NaN
# 27                             8534 Main St
# 28                                      NaN
# 29                                      NaN
# 30  Adjacent To The Chambers At City Center
# 31                             8608 Main St
# 32                             8646 Main St
# 33                             8636 Main St
# 34                             8612 Main St
# 35                                      NaN
# 36                             8654 Main St
# 37                                      NaN
# 38                             8636 Main St
# 39                             8604 Main St
# 40                              Main Street
# 41                             8588 Main St
# 42                                      NaN
# 43                            105 E Main St
# 44                             8720 Main St
# 45                    105 E Main St Ste 146
# 46                                      NaN
# 47                                      NaN
# 48                             8640 Main St
# 49                             8534 Main St
# 50                                      NaN
# 51                             8594 Main St
# 52                                      NaN
# 53                                      NaN
# 54                             8590 Main St
# 55                      118 Mill St Ste 110
# 56                     8720 Main St Ste 110
# 57                       102 Arnold Mill Rd
# 58                             8608 Main St
# 59                                      NaN
# 60                             8650 Main St
# 61                              123 Mill St
# 62                                      NaN
# 63                              Main Street
# 64                          470 Chambers St
# 65                          490 Chambers St
# 66                             8634 Main St
# 67                             8632 Main St
# 68                            105 E Main St
# 69                                  Main St
# 70                                      NaN
# 71                                      NaN
# 72                             8582 Main St
# 73                                      NaN
# 74                                      NaN
# 75                            105 E Main St
# 76                             8650 Main St
# 77                      500 Chambers Street
# 78                            103 E Main St
# 79                           116 Hubbard Rd
# 80                                      NaN
# 81                                     Uhhh
# 82                             8608 Main St
# 83                                      NaN
# 84                            105 E Main St
# 85                                      NaN
# 86                                      NaN
# 87                           250 14th St NW
# 88                                      NaN
#
#                             crossStreet                        id
# 0                                   NaN  50b3ac3fe4b0f78dc10d26e6
# 1                                   NaN  4bb498b5a187ef3b1dc84942
# 2                                   NaN  530a5c53498e3916df663037
# 3                     Townelake Parkway  593f1b4c09e2831c1992e06e
# 4                               Main St  4b2fe403f964a5200ff224e3
# 5                                   NaN  52fcdc8b498e71a5c047bca0
# 6                                   NaN  5827af34878188626acdd6e6
# 7                                   NaN  4b8e78caf964a520522433e3
# 8                        South Main St.  4be5c52a2468c928fb850043
# 9                    Towne Lake Parkway  4e1b77de62e180a4848f7564
# 10                                  NaN  4be58e302457a593d79aab15
# 11                   Towne Lake Parkway  4e692f23a80996c00616956d
# 12                                  NaN  4bc131bbf8219c746215b310
# 13                                  NaN  581be2d503fcb4100cc69b1a
# 14                                  NaN  5a80acf4e1791001a218907a
# 15                                  NaN  4f92da58e4b03828fd558c78
# 16                                  NaN  4e1f3b42887799f23ff6bc13
# 17                                  NaN  4d0f86a771e8a1cdac357bbd
# 18                                  NaN  4b845522f964a5203f2f31e3
# 19                                  NaN  52756a5611d262de749ba4b1
# 20                                  NaN  4e0e7368e4cd27fc7d30468b
# 21                                  NaN  53d0530c498ea42202e0c1d6
# 22                                  NaN  561c6c68498e249eafdcd045
# 23                                  NaN  4b3bc7e8f964a5200d7b25e3
# 24                       Wheeler Street  53d951a2498e97eab69f1c23
# 25                                  NaN  5c12924d625a66002c6c6415
# 26                                  NaN  5d1105703e8ac4002d5bed89
# 27                                  NaN  4d5c71af5d153704e4b072e7
# 28                                  NaN  4c388ea093db0f47ffba2192
# 29                                  NaN  569ccdd5498edb460ff420a0
# 30                                  NaN  4ed674ae2c5b3d826ebace86
# 31                                  NaN  4d602a089f67f04d9f9075fb
# 32                                  NaN  4ed137b9b634dd29927ef0b7
# 33                                  NaN  4e57c968aeb7eff130d0854e
# 34                                  NaN  4bbcd9a28ec3d13a88521b28
# 35                                  NaN  58ec154a18384c12203ec7f1
# 36                                  NaN  4f86f7ebe4b0270511557731
# 37                                  NaN  4cba2a21bac93704c3cee97c
# 38                                  NaN  58001ab038fa3dc50cdfb5b3
# 39                                  NaN  4b60984bf964a52050ef29e3
# 40                                  NaN  4f5a6b4ce4b09f2e904fe1de
# 41                                  NaN  4b9199dff964a520e5c833e3
# 42                                  NaN  57ffbdf238faa206848d3218
# 43                                  NaN  4b7b51baf964a520245e2fe3
# 44                                  NaN  564500b7498edf3cd0e13bf9
# 45                                  NaN  4b2cfb29f964a520becb24e3
# 46                                  NaN  56452883498ed0ce5c0e05bd
# 47                                  NaN  52910ad611d2654437baa30d
# 48  Elm St. Across from old Train Depot  4bce1c2ec564ef3b33adedf0
# 49                                  NaN  4f22a9afe4b0dc27b78e9fb3
# 50                                  NaN  4e482b1618a8f9804ce06ad9
# 51                                  NaN  4cb63ba655af224b7065987e
# 52                                  NaN  4f45588be4b04ef91c679115
# 53                                  NaN  57fc046ecd10f334dbad01da
# 54                      Towne Lake Pkwy  4c82442151ada1cddd5d1a10
# 55                                  NaN  59d46afe5ba0465b5c7f5701
# 56                                  NaN  5852b53ca83a2560d53e7ab1
# 57                                  NaN  4cd315e6baf2f04d9906ada3
# 58                                  NaN  4e3f16318877b00cfc5da5c2
# 59                                  NaN  4ccf2c395b5ca35d247174f0
# 60                                  NaN  4debde577d8b6c7a53648709
# 61                                  NaN  4fa2a73de4b0b4fd557d1d28
# 62                                  NaN  4f7f0a4ae4b049fd33ab33f4
# 63                                  NaN  52278dc311d2711d329b916b
# 64                     Arnold Mill Road  4cd5bb7389eb6dcb79e92a1e
# 65                                  NaN  4c24e80bf7ced13afb9c236d
# 66                                  NaN  4a95676af964a520152320e3
# 67                                  NaN  4bb0b223f964a5209e553ce3
# 68                                  NaN  50afa23ee4b0caa69b917fcd
# 69                      Towne Lake Pkwy  51437a9ae4b00a3000635772
# 70                                  NaN  4bae5668f964a5209aa43be3
# 71                                  NaN  4c07c977221620a1b051f775
# 72                                  NaN  4d08dad9790fa093cf9fc573
# 73                                  NaN  50c0b718e4b08c1f64385538
# 74                                  NaN  51c0aaf0498ecb98ec5f2e05
# 75                                  NaN  4c405da7520fa5935de5c7ac
# 76                                  NaN  4fd128f9e4b0b895948a0966
# 77                              Main St  5050c5a6e4b030bfc6e8d67b
# 78                                  NaN  4c4da9cefb742d7f0d211b2d
# 79                       Wheeler Street  4bb8f8bf98c7ef3bcfa33102
# 80                                  NaN  4e0b1e4722713e13018ede79
# 81                                  Idk  4f328aace4b092d58cc77a7e
# 82                                  NaN  50297527e4b029a5bc950338
# 83                                  NaN  4f1f41dae4b046c2fefffa6c
# 84                                  NaN  4ea650e6d5fbffc9192bfc75
# 85                                  NaN  4e1b0486d22d8a338fe93ef7
# 86                                  NaN  553fbd6e498e1886320b6734
# 87                                  NaN  4c9e2adc03133704f40566d5
# 88                                  NaN  579cba59498e975fa65c315d

# %% [markdown]
# ### Get the distinct categories - we will need to select only the restaurant type categories(Restaurant, gastropub, food truck, etc)

# %%
wcats=pysql('select distinct categories from wdataframe_filtered')
wcats
