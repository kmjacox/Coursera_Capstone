# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %%
#Uncomment these if needed
# !conda install -c conda-forge wikipedia --yes
print('Wikipedia Done')
# !conda install -c conda-forge pandasql --yes
print('Pandasql Done')
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
print('geopy Done')
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
print('Folium Done')

# !conda install -c conda-forge matplotlib --yes # uncomment this line if you haven't completed the Foursquare API lab
print('matplotlib Done')
# !conda install -c conda-forge scikit-learn --yes # uncomment this line if you haven't completed the Foursquare API lab
print('scikit-learn Done')
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - wikipedia
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.8.0       |           py37_0         143 KB  conda-forge
#     soupsieve-1.9.3            |           py37_0          57 KB  conda-forge
#     wikipedia-1.4.0            |             py_2          13 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         214 KB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import wikipedia as wp


import pandasql as pdsql

pysql = lambda q: pdsql.sqldf(q, globals())


import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans


import folium # map rendering library

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Set Foursquare variables
CLIENT_ID = 'U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1' # your Foursquare ID
CLIENT_SECRET = '3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y' # your Foursquare Secret
VERSION = '20180604'
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1
# CLIENT_SECRET:3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y

# %%
from geopy.geocoders import Nominatim

waddress = 'Woodstock, GA'
raddress = 'Roswell, GA'
geolocator = Nominatim(user_agent="my_explorer")
wlocation = geolocator.geocode(waddress)
rlocation = geolocator.geocode(raddress)
wlatitude = wlocation.latitude
wlongitude = wlocation.longitude
rlatitude = rlocation.latitude
rlongitude = rlocation.longitude
print('The geograpical coordinates of '+waddress+' are {}, {}.'.format(wlatitude, wlongitude))
print('The geograpical coordinates of '+raddress+' are {}, {}.'.format(rlatitude, rlongitude))
# Out:
# The geograpical coordinates of Woodstock, GA are 34.1014112, -84.5192192.
# The geograpical coordinates of Roswell, GA are 34.02332, -84.360022.

# %%
# Make our search
search_query = ''
radius = 10000
categoryid='4d4b7105d754a06374d81259'
LIMIT=200
print(search_query + ' .... OK!')
# Out:
#  .... OK!

# %%
#wurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, wlatitude, wlongitude, VERSION, search_query, radius, LIMIT)
#wurl
search_query='30189'
wurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&near={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, wlatitude, wlongitude, VERSION, search_query, radius, LIMIT)
wurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1&client_secret=3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y&ll=34.1014112,-84.5192192&v=20180604&query=&radius=10000&limit=200'

# %%
rurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, rlatitude, rlongitude, VERSION, search_query, radius, LIMIT)
rurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1&client_secret=3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y&ll=34.02332,-84.360022&v=20180604&query=&radius=10000&limit=200'

# %% [markdown]
# ### Let's get the data we need for the first city:

# %%
#Get Results for Woodstock
import requests
wresults = requests.get(wurl).json()

# %%
# assign relevant part of JSON to venues
wvenues = wresults['response']['venues']

# tranform venues into a dataframe
wdataframe = json_normalize(wvenues)

# %%
# keep only columns that include venue name, and anything that is associated with location
wfiltered_columns = ['name', 'categories'] + [col for col in wdataframe.columns if col.startswith('location.')] + ['id']
wdataframe_filtered = wdataframe.loc[:, wfiltered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
wdataframe_filtered['categories'] = wdataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
wdataframe_filtered.columns = [column.split('.')[-1] for column in wdataframe_filtered.columns]

# %%
wdataframe_filtered=wdataframe_filtered.drop(['labeledLatLngs','formattedAddress'], axis=1)
wdataframe_filtered.head()
# Out:
#                         name      categories                      address  \
# 0  Rose Creek Public Library         Library         4476 Towne Lake Pkwy
# 1              Renasant Bank            Bank         4475 Towne Lake Pkwy
# 2                     Publix   Grocery Store         4403 Towne Lake Pkwy
# 3              The UPS Store  Shipping Store  1025 Rose Creek Dr, Ste 620
# 4         Hobgood Park Track           Track        6688 Bells Ferry Road
#
#          lat        lng  distance postalCode  cc       city state  \
# 0  34.129532 -84.572559      5827      30189  US  Woodstock    GA
# 1  34.128016 -84.571655      5667      30189  US  Woodstock    GA
# 2  34.127246 -84.571159      5584      30189  US  Woodstock    GA
# 3  34.127280 -84.573284      5755      30189  US  Woodstock    GA
# 4  34.129942 -84.585281      6866      30189  US  Woodstock    GA
#
#          country    crossStreet                        id
# 0  United States            NaN  4c28ebb9ed0ac9b6d0fc60aa
# ...

# %% [markdown]
# ### Get the distinct categories - we will need to select only the restaurant type categories(Restaurant, gastropub, food truck, etc)

# %% [markdown]
# Review the category list for categories that could be restaurants.  using just 'Restaurant' does not give us the whiole picture.

# %%
pysql = lambda q: pdsql.sqldf(q, globals())
wcats=pysql('select distinct categories from wdataframe_filtered where categories like \'%pub%\' OR categories like \'Brewery%\' OR categories like \'Steak%\' OR categories like \'BBQ%\' OR categories like \'%Pub\'  OR categories like \'%Restaurant%\' OR categories like \'%Bar\' OR categories like \'%Food%\'  OR categories like \'%Cafe\' OR categories like \'Pizza%\' ')

# %% [markdown]
# ### Get our final dataset for only the categories we are looking at:

# %%
wdf=pysql('select * from wdataframe_filtered where categories in (select categories from wcats)')
wdf
# Out:
#                           name          categories        lat        lng  \
# 0             Rootstock & Vine            Wine Bar  34.101276 -84.519561
# 1        Freight Kitchen & Tap           Gastropub  34.100808 -84.519316
# 2                   Vingenzo's  Italian Restaurant  34.102059 -84.518690
# 3            Partners II Pizza         Pizza Place  34.100931 -84.519577
# 4                         IPPS  Italian Restaurant  34.102253 -84.519344
# 5                  Truck & Tap                 Bar  34.100343 -84.519908
# 6           Dominic’s NY Pizza          Food Truck  34.100212 -84.520036
# 7                   Brainfoods          Food Truck  34.100373 -84.520214
# 8      Gyro Chef Mediterranean          Food Truck  34.100312 -84.520127
# 9               Campo's Garage          Sports Bar  34.101487 -84.519375
# 10  deep south biscuit company          Food Truck  34.100392 -84.520219
# 11                  The Pickle          Food Truck  34.100316 -84.519953
# ...

# %% [markdown]
# ### Get data for second city

# %%
#Get Results for Roswell
rresults = requests.get(rurl).json()

# %%
# assign relevant part of JSON to venues
rvenues = rresults['response']['venues']

# tranform venues into a dataframe
rdataframe = json_normalize(rvenues)

# %%
# keep only columns that include venue name, and anything that is associated with location
rfiltered_columns = ['name', 'categories'] + [col for col in rdataframe.columns if col.startswith('location.')] + ['id']
rdataframe_filtered = rdataframe.loc[:, rfiltered_columns]

# filter the category for each row
rdataframe_filtered['categories'] = rdataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
rdataframe_filtered.columns = [column.split('.')[-1] for column in rdataframe_filtered.columns]

# %%
rdataframe_filtered=rdataframe_filtered.drop(['labeledLatLngs','formattedAddress'], axis=1)

# %%
pysql = lambda q: pdsql.sqldf(q, globals())
rcatsall=pysql('select distinct categories from rdataframe_filtered')
rcats=pysql('select distinct categories from rdataframe_filtered where categories like \'%pub%\' OR categories like \'Brewery%\' OR categories like \'Steak%\' OR categories like \'BBQ%\' OR categories like \'%Pub\'  OR categories like \'%Restaurant%\' OR categories like \'%Bar\' OR categories like \'%Food%\'  OR categories like \'%Cafe\' OR categories like \'Pizza%\' ')

# %%
rdf=pysql('select * from rdataframe_filtered where categories in (select categories from rcats)')
rdf
# Out:
#                           name                 categories  \
# 0                  VAS Kouzina           Greek Restaurant
# 1                      Ceviche         Mexican Restaurant
# 2                  1920 Tavern                        Bar
# 3         The Salt Factory Pub        American Restaurant
# 4         Gate City Brewing Co                    Brewery
# 5               Local On North        American Restaurant
# 6        The Real Fix Pizzeria                Pizza Place
# 7                 Loyal Tavern                 Restaurant
# 8                       Pastis                        Bar
# 9          Mac McGee Irish Pub                        Pub
# 10          Roswell Provisions                       Food
# 11                  El zorrito         Mexican Restaurant
# 12                   Le Bistro          French Restaurant
# 13                Fix Pizzeria                Pizza Place
# 14      Zest Sushi & Tapas Bar           Sushi Restaurant
# ...

# %%
fullset=pysql('select name, categories, address, crossStreet, lat, lng, distance, postalCode, cc, city, state, country, id from wdf union select name, categories, address, crossStreet, lat, lng, distance, postalCode, cc, city, state, country, id from rdf')

# %%
fullset
# Out:
#                           name                 categories  \
# 0                  1920 Tavern                        Bar
# 1               Angelfire7 BBQ                 Food Truck
# 2        Behind The Bar @ Roux                        Bar
# 3                   Brainfoods                 Food Truck
# 4               Campo's Garage                 Sports Bar
# 5                    Carne 250                  BBQ Joint
# 6                      Ceviche         Mexican Restaurant
# 7           Dominic’s NY Pizza                 Food Truck
# 8                    El Zarape         Mexican Restaurant
# 9                   El zorrito         Mexican Restaurant
# 10                Fix Pizzeria                Pizza Place
# 11     Freelands Pizza And Pub                Pizza Place
# 12       Freight Kitchen & Tap                  Gastropub
# 13        Gaslight Bar & Grill                        Bar
# 14        Gate City Brewing Co                    Brewery
# ...

# %%
search_query='30189'
wurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&near={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, wlatitude, wlongitude, VERSION, search_query, radius, LIMIT)
wurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U1TSCAOBPQDTO1JTQKWHUAZBTWEVPXNOIYE5KVN32J0PCFT1&client_secret=3ZMFAU5QWV3UAEUJGHKRX5XMSMHJLYZDYN3FK25IV0CNUC2Y&ll=34.1014112,-84.5192192&v=20180604&near=30189&radius=10000&limit=200'
